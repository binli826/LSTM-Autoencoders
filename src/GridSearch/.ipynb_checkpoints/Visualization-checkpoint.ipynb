# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from numpy.random import randn
import pandas as pd
import numpy as np

# %% [markdown]
# # HTTP

# %%
f = open("C:/Users/Bin/Desktop/Thesis/code/src/GridSearch/http_results.txt","r")
data = []
for _ in range(10):
    tmp = []
    for _ in range(10):
        tmp.append(float(f.readline().strip("[|]\n").split(", ")[-1]))
    data.append(tmp)
    
fig, ax = plt.subplots()

cax = ax.imshow(data, interpolation='lanczos', cmap=cm.magma)
ax.set_title('Grid search (HTTP)')
ax.set_xticks(range(0,10))
ax.set_xticklabels(range(10,110,10))
ax.set_xlabel("window length")
ax.set_yticks(range(0,10))
ax.set_yticklabels(range(1,11))
ax.set_ylabel("Hidden layer size")
cbar = fig.colorbar(cax, ticks=[0.48,1.00,2.62])
cax.set_clim(0.48,2.62)
cbar.ax.set_yticklabels(['0.48','1.00',"2.62"])  
cbar.ax.set_ylabel("Error(normal) / Error(anomaly)")
plt.show()

# %%
np.array(data).ravel().max()
# Out:
# 2.6261268000000002

# %% [markdown]
# # SMTP

# %%
f = open("C:/Users/Bin/Desktop/Thesis/code/src/GridSearch/smtp_results.txt","r")
data = []
for _ in range(10):
    tmp = []
    for _ in range(10):
        tmp.append(float(f.readline().strip("[|]\n").split(", ")[-1]))
    data.append(tmp)
    
fig, ax = plt.subplots()

cax = ax.imshow(data, interpolation='lanczos', cmap=cm.magma)
ax.set_title('Grid search (SMTP)')
ax.set_xticks(range(0,10))
ax.set_xticklabels(range(10,110,10))
ax.set_xlabel("window length")
ax.set_yticks(range(0,10))
ax.set_yticklabels(range(1,11))
ax.set_ylabel("Hidden layer size")
cax.set_clim(0,4.75)
cbar = fig.colorbar(cax, ticks=[0,1.00,4.75])
cbar.ax.set_yticklabels(["0","1.00","4.75"])  
cbar.ax.set_ylabel("Error(normal) / Error(anomaly)")
plt.show()

# %% [markdown]
# # Forest

# %%
f = open("C:/Users/Bin/Desktop/Thesis/code/src/GridSearch/forest_results.txt","r")
data = []
for _ in range(10):
    tmp = []
    for _ in range(10):
        tmp.append(float(f.readline().strip("[|]\n|]").split(", ")[-1]))
    data.append(tmp)
    
fig, ax = plt.subplots()

cax = ax.imshow(data, interpolation='lanczos', cmap=cm.magma)
ax.set_title('Grid search (Forest)')
ax.set_xticks(range(0,10))
ax.set_xticklabels(range(10,110,10))
ax.set_xlabel("window length")
ax.set_yticks(range(0,10))
ax.set_yticklabels(range(1,11))
ax.set_ylabel("Hidden size")
cbar = fig.colorbar(cax, ticks=[0.85,1.0,1.25])
cbar.ax.set_yticklabels(['0.85','1.00',"1.25"])  
cax.set_clim(0.85,1.4)
cbar.ax.set_ylabel("Error(normal) / Error(anomaly)")
plt.show()

# %% [markdown]
# # Power

# %%
f = open("C:/Users/Bin/Desktop/Thesis/code/src/GridSearch/power_results.txt","r")
data = []
for _ in range(10):
    tmp = []
    for _ in range(9):
        tmp.append(float(f.readline().strip("[|]\n|]").split(", ")[-1]))
    data.append(tmp)
    
fig, ax = plt.subplots()

cax = ax.imshow(data, interpolation='lanczos', cmap=cm.magma)
ax.set_title('Grid search (Power)')
ax.set_xticks(range(0,9))
ax.set_xticklabels(range(10,100,10))
ax.set_xlabel("window length")
ax.set_yticks(range(0,10))
ax.set_yticklabels(range(5,55,5))
ax.set_ylabel("Hidden size")
cbar = fig.colorbar(cax, ticks=[0.15,1.0,1.53])
cbar.ax.set_yticklabels(['0.15','1.00',"1.53"])  
cax.set_clim(0.148,1.53)
cbar.ax.set_ylabel("Error(normal) / Error(anomaly)")
plt.show()
