# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
power = pd.read_csv("C:/Users/Bin/Documents/Datasets/EncDec-AD dataset/power_data.txt",names=["power_demand"])

# %%
sub_power = pd.Series(power[490:51*84*8+490].reset_index(drop=True)["power_demand"])
sub_power = sub_power[::8].reset_index(drop=True)
sub_power = sub_power.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(sub_power)
sub_power = scaler.transform(sub_power) 

sub_power_ = np.array([sub_power[t][0] for t in range(sub_power.shape[0])])
sub_power_list = [sub_power_[t*84:(t+1)*84] for t in range(51)]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
anomalous_indices = [11,12,16,17,19,38,50]
normal_indices = list(set(range(51))-set(anomalous_indices))
dataset_normal = [sub_power_list[i] for i in normal_indices]
dataset_anomalous = [sub_power_list[j] for j in anomalous_indices]

# %%
label = np.array(['anomaly' for _ in range(51)])
label[normal_indices] = 'normal'
label = [[x]*84 for x in label]
label = np.array(label).ravel()

# %%
sub_power.shape
# Out:
# (4284, 1)

# %%
data = pd.concat((pd.DataFrame(sub_power),pd.Series(label)),axis=1)

# %%
#data.to_csv("C:/Users/Bin/Documents/Datasets/EncDec-AD dataset/power_data_labeled_unscaled.csv",header=None,index=None)

# %%
test_set = data[84*13:]

# %% [markdown]
# # Autoencoder anomaly detection

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import time

# %% [markdown]
# ## Reload power_demand autoencoder from disk

# %%
#modelpath_root ="C:/Users/Bin/Desktop/Thesis/tmp/EncDecADModel_online_init/power_demand/Try1_2_40_84/"
modelpath_root ="C:/Users/Bin/Desktop/Thesis/tmp/EncDecADModel_online_init/power_demand/Try8_1_40_84/"
modelmeta_p = modelpath_root + "LSTMAutoencoder_power_1_40_84_para.ckpt.meta"
step_num = 84
hidden_num = 40
batch_num = 1
elem_num = 1

# %%
#test_set_list = [test_set.iloc[:3192,0].as_matrix().reshape(19,2,84,1)[a] for a in range(19)]
test_set_list = [test_set.iloc[:,0].as_matrix().reshape(38,1,84,1)[a] for a in range(38)]

# %%
sess = tf.Session()
saver = tf.train.import_meta_graph(modelmeta_p) # load trained gragh, but without the trained parameters
saver.restore(sess,tf.train.latest_checkpoint(modelpath_root))
graph = tf.get_default_graph()

p_input = graph.get_tensor_by_name("p_input:0")
p_inputs = [tf.squeeze(t, [1]) for t in tf.split(p_input, step_num, 1)] 
#        p_is_training = tf.placeholder(tf.bool)
p_is_training = graph.get_tensor_by_name("is_training_:0")

input_= tf.transpose(tf.stack(p_inputs), [1, 0, 2])    
output_ = graph.get_tensor_by_name("decoder/output_:0")

tensor_mu = graph.get_tensor_by_name("mu:0")
tensor_sigma = graph.get_tensor_by_name("sigma:0")
tensor_threshold = graph.get_tensor_by_name("threshold:0")

loss_ = graph.get_tensor_by_name("decoder/loss:0")
train_ = graph.get_operation_by_name("cond/train_")

mu = sess.run(tensor_mu)
sigma = sess.run(tensor_sigma)
threshold = sess.run(tensor_threshold)
# Out:
# INFO:tensorflow:Restoring parameters from C:/Users/Bin/Desktop/Thesis/tmp/EncDecADModel_online_init/power_demand/Try8_1_40_84/LSTMAutoencoder_power_1_40_84_para.ckpt

# %%
print(mu.shape,sigma.shape,threshold)
# Out:
# (84, 1) (84, 84) 1.62739e+09

# %% [markdown]
# # Retrain according to performance

# %% [markdown]
# ## 2. retrain when prediction performance < t

# %%
eta = 0.6 #privous parameters plays 60% role during the parameter updating

# %%
def scoring(err,mu,sigma,batch_num,step_num):
    for window in range(batch_num):
        temp = np.dot(abs((err[window] - mu )).T  , np.linalg.inv(sigma))
        s = np.dot(temp,(abs(err[window] - mu )))[0,0]
    return s

# %%
def update_parameter(errBuffer,mu,sigma,eta,threshold,score):       
        tmp_errBuffer = errBuffer[-3:] if len(errBuffer)>3 else errBuffer
        err_vec_array = np.array(tmp_errBuffer)
        __mu = np.mean(err_vec_array,axis=0)
        mu = mu*eta + __mu*(1-eta)

        sigma_list = [] 
        for vec in tmp_errBuffer:
            sub_sigma = np.dot((np.array(vec)-mu),(np.array(vec)-mu).T)
            sigma_list.append(sub_sigma)
        __sigma = sum(sigma_list)/(len(sigma_list)-1)
        sigma = __sigma


        threshold = threshold*eta + score*(1-eta)

        return mu,sigma,threshold

# %%
input_buffer = []
output_buffer = []
#anomaly_batches = [0,2,3,18]
anomaly_batches = [3,4,6,25,37]
count = -1
loss_overall = []
err_sum_0 = 0
dataBuffer = []
scoreBuffer = []
a_scoreBuffer = []
n_scoreBuffer = []
errBuffer = []
errSumBuffer = []
for data in test_set_list:
    count +=1
    (input_n, output_n) = sess.run([input_, output_], {p_input: data, p_is_training: False})
    
    input_buffer.append(input_n)
    output_buffer.append(output_n)
    
    err = abs(input_n-output_n).reshape(-1,step_num,elem_num)
    score = scoring(err,mu,sigma,batch_num,step_num)
    scoreBuffer.append(score)

 #   errBuffer.append(sum(abs((err.ravel()-mu.ravel()))))
    errBuffer += [abs(input_n-output_n)[i] for i in range(abs(input_n-output_n).shape[0])]
    if count in anomaly_batches: 
        continue    
    else:
        dataBuffer.append(data)
    
    if count == 0:
        err_sum_0 = sum(abs(input_n- output_n).ravel())

    
    
    # retrain autoencoder, when sum reconstruction error larger than initial max r.error
    error_sum = sum(abs(input_n-output_n).ravel())
    errSumBuffer.append(error_sum)
    if error_sum >= err_sum_0+0.5 or count ==0:
        print("Retrain at batch number %d\n"%count)
        buffer = dataBuffer[-3:] if len(dataBuffer)>3 else dataBuffer
        loss = []
        for i in range(100):
            ind = np.random.randint(0,len(buffer))
            d = buffer[ind]
            (loss_val, _) = sess.run([loss_, train_], {p_input: d,p_is_training : True})
            loss.append(loss_val)
            print('Retrain-iter %d:' % (i + 1), loss_val)
        loss_overall.append(loss_val)
        pd.Series(loss).plot(title="Loss")
    
    # update parameters, if make wrong prediction
    print("Score%.3f,threshold%.3f"%(score,threshold))
    if score > threshold:
        if count in anomaly_batches:
            print("Correct alarm!!!")
        else:
            print("Wrong alarm! Use this batch to update parameters...")
            mu,sigma,threshold = update_parameter(errBuffer,mu,sigma,eta,threshold,score)
            print(threshold)
    else:
        if count in anomaly_batches:
            print("Miss alarm! Use this batch to update parameters...")       
            mu,sigma,threshold = update_parameter(errBuffer,mu,sigma,eta,threshold,score)
            print(threshold)
    
        else:
            print("Correct prediction!!!")
# Out:
# Retrain at batch number 0
#
# Retrain-iter 1: 0.00239909
# Retrain-iter 2: 0.00220665
# Retrain-iter 3: 0.00189212
# Retrain-iter 4: 0.0016449
# Retrain-iter 5: 0.00146771
# Retrain-iter 6: 0.0013863
# Retrain-iter 7: 0.00142642
# Retrain-iter 8: 0.00149542
# Retrain-iter 9: 0.001477
# Retrain-iter 10: 0.00136849
# Retrain-iter 11: 0.00123074
# Retrain-iter 12: 0.00109649
# Retrain-iter 13: 0.00100285
# Retrain-iter 14: 0.00100093
# Retrain-iter 15: 0.00106081
# Retrain-iter 16: 0.00108558
# Retrain-iter 17: 0.00104658
# Retrain-iter 18: 0.000986191
# Retrain-iter 19: 0.000928304
# Retrain-iter 20: 0.000886702
# Retrain-iter 21: 0.000886775
# Retrain-iter 22: 0.000916733
# Retrain-iter 23: 0.000930203
# Retrain-iter 24: 0.000911362
# Retrain-iter 25: 0.000878029
# Retrain-iter 26: 0.00084249
# Retrain-iter 27: 0.000816084
# Retrain-iter 28: 0.00081503
# Retrain-iter 29: 0.000831405
# Retrain-iter 30: 0.000837164
# Retrain-iter 31: 0.000823599
# Retrain-iter 32: 0.000802803
# Retrain-iter 33: 0.000784463
# Retrain-iter 34: 0.000775691
# Retrain-iter 35: 0.000780447
# Retrain-iter 36: 0.000788762
# Retrain-iter 37: 0.000787609
# Retrain-iter 38: 0.000778429
# Retrain-iter 39: 0.000769379
# Retrain-iter 40: 0.000763051
# Retrain-iter 41: 0.000760105
# Retrain-iter 42: 0.000760774
# Retrain-iter 43: 0.000760889
# Retrain-iter 44: 0.000757074
# Retrain-iter 45: 0.000751558
# Retrain-iter 46: 0.000746607
# Retrain-iter 47: 0.00074203
# Retrain-iter 48: 0.0007388
# Retrain-iter 49: 0.000737562
# Retrain-iter 50: 0.000736122
# Retrain-iter 51: 0.000732957
# Retrain-iter 52: 0.000729145
# Retrain-iter 53: 0.000725655
# Retrain-iter 54: 0.000722811
# Retrain-iter 55: 0.000721218
# Retrain-iter 56: 0.000720382
# Retrain-iter 57: 0.000718752
# Retrain-iter 58: 0.00071609
# Retrain-iter 59: 0.000713378
# Retrain-iter 60: 0.000711053
# Retrain-iter 61: 0.000709163
# Retrain-iter 62: 0.000707801
# Retrain-iter 63: 0.000706493
# Retrain-iter 64: 0.00070465
# Retrain-iter 65: 0.00070245
# Retrain-iter 66: 0.000700323
# Retrain-iter 67: 0.000698363
# Retrain-iter 68: 0.000696673
# Retrain-iter 69: 0.000695281
# Retrain-iter 70: 0.000693836
# Retrain-iter 71: 0.000692073
# Retrain-iter 72: 0.000690182
# Retrain-iter 73: 0.000688383
# Retrain-iter 74: 0.000686746
# Retrain-iter 75: 0.0006853
# Retrain-iter 76: 0.000683926
# Retrain-iter 77: 0.000682406
# Retrain-iter 78: 0.00068074
# Retrain-iter 79: 0.000679097
# Retrain-iter 80: 0.000677547
# Retrain-iter 81: 0.000676077
# Retrain-iter 82: 0.000674661
# Retrain-iter 83: 0.000673238
# Retrain-iter 84: 0.000671748
# Retrain-iter 85: 0.000670237
# Retrain-iter 86: 0.000668754
# Retrain-iter 87: 0.000667303
# Retrain-iter 88: 0.000665889
# Retrain-iter 89: 0.000664518
# Retrain-iter 90: 0.000663145
# Retrain-iter 91: 0.000661752
# Retrain-iter 92: 0.000660356
# Retrain-iter 93: 0.000658976
# Retrain-iter 94: 0.000657616
# Retrain-iter 95: 0.000656287
# Retrain-iter 96: 0.000654978
# Retrain-iter 97: 0.000653665
# Retrain-iter 98: 0.000652348
# Retrain-iter 99: 0.000651039
# Retrain-iter 100: 0.000649742
# Score-17092195328.000,threshold1767522380.800
# Correct prediction!!!
# Score-8785777664.000,threshold1767522380.800
# Correct prediction!!!
# Score-8570392064.000,threshold1767522380.800
# Correct prediction!!!
# Score-17255411712.000,threshold1767522380.800
# Correct prediction!!!
# Score-15606846464.000,threshold1767522380.800
# Correct prediction!!!
# Score-11233783808.000,threshold1767522380.800
# Correct prediction!!!
# Score-17938386944.000,threshold1767522380.800
# Correct prediction!!!
# Score-20601341952.000,threshold1767522380.800
# Correct prediction!!!
# Score-9822908416.000,threshold1767522380.800
# Correct prediction!!!
# Retrain at batch number 12
#
# Retrain-iter 1: 0.00455317
# Retrain-iter 2: 0.00150013
# Retrain-iter 3: 0.00146773
# Retrain-iter 4: 0.000793643
# Retrain-iter 5: 0.000864508
# Retrain-iter 6: 0.00184187
# Retrain-iter 7: 0.000881769
# Retrain-iter 8: 0.00140461
# Retrain-iter 9: 0.00214435
# Retrain-iter 10: 0.00124369
# Retrain-iter 11: 0.00229984
# Retrain-iter 12: 0.00070474
# Retrain-iter 13: 0.00196193
# Retrain-iter 14: 0.00178409
# Retrain-iter 15: 0.00182873
# Retrain-iter 16: 0.000938501
# Retrain-iter 17: 0.00158121
# Retrain-iter 18: 0.00158382
# Retrain-iter 19: 0.00155707
# Retrain-iter 20: 0.000838994
# Retrain-iter 21: 0.00188025
# Retrain-iter 22: 0.00186942
# Retrain-iter 23: 0.00127243
# Retrain-iter 24: 0.00174502
# Retrain-iter 25: 0.00167404
# Retrain-iter 26: 0.0015815
# Retrain-iter 27: 0.0014315
# Retrain-iter 28: 0.00122418
# Retrain-iter 29: 0.00221295
# Retrain-iter 30: 0.000856108
# Retrain-iter 31: 0.000714054
# Retrain-iter 32: 0.00196962
# Retrain-iter 33: 0.00188392
# Retrain-iter 34: 0.00170309
# Retrain-iter 35: 0.000666025
# Retrain-iter 36: 0.00144932
# Retrain-iter 37: 0.0012099
# Retrain-iter 38: 0.000723137
# Retrain-iter 39: 0.00082881
# Retrain-iter 40: 0.000820478
# Retrain-iter 41: 0.00251743
# Retrain-iter 42: 0.00116329
# Retrain-iter 43: 0.00212475
# Retrain-iter 44: 0.00144241
# Retrain-iter 45: 0.000635167
# Retrain-iter 46: 0.00127607
# Retrain-iter 47: 0.00109712
# Retrain-iter 48: 0.000787436
# Retrain-iter 49: 0.00104895
# Retrain-iter 50: 0.00253446
# Retrain-iter 51: 0.00225557
# Retrain-iter 52: 0.000553408
# Retrain-iter 53: 0.000618663
# Retrain-iter 54: 0.000724526
# Retrain-iter 55: 0.0018125
# Retrain-iter 56: 0.00144816
# Retrain-iter 57: 0.00107241
# Retrain-iter 58: 0.00256774
# Retrain-iter 59: 0.00269076
# Retrain-iter 60: 0.00239113
# Retrain-iter 61: 0.0013843
# Retrain-iter 62: 0.00162011
# Retrain-iter 63: 0.00173068
# Retrain-iter 64: 0.00142476
# Retrain-iter 65: 0.00168517
# Retrain-iter 66: 0.00121914
# Retrain-iter 67: 0.00148894
# Retrain-iter 68: 0.00168519
# Retrain-iter 69: 0.00130248
# Retrain-iter 70: 0.00242942
# Retrain-iter 71: 0.00110593
# Retrain-iter 72: 0.00254148
# Retrain-iter 73: 0.0021645
# Retrain-iter 74: 0.000857984
# Retrain-iter 75: 0.000922818
# Retrain-iter 76: 0.00171695
# Retrain-iter 77: 0.00175436
# Retrain-iter 78: 0.00194067
# Retrain-iter 79: 0.000918919
# Retrain-iter 80: 0.00169712
# Retrain-iter 81: 0.00133347
# Retrain-iter 82: 0.00117671
# Retrain-iter 83: 0.000760864
# Retrain-iter 84: 0.00102
# Retrain-iter 85: 0.00107843
# Retrain-iter 86: 0.00283091
# Retrain-iter 87: 0.000584801
# Retrain-iter 88: 0.00124346
# Retrain-iter 89: 0.00119912
# Retrain-iter 90: 0.00204452
# Retrain-iter 91: 0.000648397
# Retrain-iter 92: 0.000683811
# Retrain-iter 93: 0.00063571
# Retrain-iter 94: 0.00119377
# Retrain-iter 95: 0.000520277
# Retrain-iter 96: 0.00199145
# Retrain-iter 97: 0.000478558
# Retrain-iter 98: 0.0019874
# Retrain-iter 99: 0.00183203
# Retrain-iter 100: 0.00140887
# Score-14604976128.000,threshold1767522380.800
# Correct prediction!!!
# Score-15585965056.000,threshold1767522380.800
# Correct prediction!!!
# Score-8047441920.000,threshold1767522380.800
# Correct prediction!!!
# Score-8431020544.000,threshold1767522380.800
# Correct prediction!!!
# Score-18084728832.000,threshold1767522380.800
# Correct prediction!!!
# Score-9715449856.000,threshold1767522380.800
# Correct prediction!!!
# Score-1361828096.000,threshold1767522380.800
# Correct prediction!!!
# Score-2088434176.000,threshold1767522380.800
# Correct prediction!!!
# Retrain at batch number 20
#
# Retrain-iter 1: 0.000986081
# Retrain-iter 2: 0.00150923
# Retrain-iter 3: 0.000732694
# Retrain-iter 4: 0.000787481
# Retrain-iter 5: 0.000788625
# Retrain-iter 6: 0.000982263
# Retrain-iter 7: 0.000922349
# Retrain-iter 8: 0.00230481
# Retrain-iter 9: 0.000515431
# Retrain-iter 10: 0.000401061
# Retrain-iter 11: 0.000903673
# Retrain-iter 12: 0.000444036
# Retrain-iter 13: 0.000439755
# Retrain-iter 14: 0.000395739
# Retrain-iter 15: 0.000351355
# Retrain-iter 16: 0.000999218
# Retrain-iter 17: 0.000855257
# Retrain-iter 18: 0.00188987
# Retrain-iter 19: 0.000620228
# Retrain-iter 20: 0.00124469
# Retrain-iter 21: 0.00143539
# Retrain-iter 22: 0.00137652
# Retrain-iter 23: 0.000766307
# Retrain-iter 24: 0.00134572
# Retrain-iter 25: 0.000798445
# Retrain-iter 26: 0.00155035
# Retrain-iter 27: 0.00163022
# Retrain-iter 28: 0.000452943
# Retrain-iter 29: 0.000414276
# Retrain-iter 30: 0.000348601
# Retrain-iter 31: 0.000797282
# Retrain-iter 32: 0.000833476
# Retrain-iter 33: 0.000747741
# Retrain-iter 34: 0.000447769
# Retrain-iter 35: 0.00152519
# Retrain-iter 36: 0.000549063
# Retrain-iter 37: 0.000568361
# Retrain-iter 38: 0.00127888
# Retrain-iter 39: 0.00128766
# Retrain-iter 40: 0.000694863
# Retrain-iter 41: 0.000648457
# Retrain-iter 42: 0.00055326
# Retrain-iter 43: 0.00050509
# Retrain-iter 44: 0.000624145
# Retrain-iter 45: 0.000622081
# Retrain-iter 46: 0.000407511
# Retrain-iter 47: 0.000757058
# Retrain-iter 48: 0.000721167
# Retrain-iter 49: 0.000630168
# Retrain-iter 50: 0.00150058
# Retrain-iter 51: 0.00138117
# Retrain-iter 52: 0.000848804
# Retrain-iter 53: 0.00143911
# Retrain-iter 54: 0.00132109
# Retrain-iter 55: 0.00135063
# Retrain-iter 56: 0.00141799
# Retrain-iter 57: 0.000610675
# Retrain-iter 58: 0.00058425
# Retrain-iter 59: 0.00156373
# Retrain-iter 60: 0.000429604
# Retrain-iter 61: 0.00143186
# Retrain-iter 62: 0.000601173
# Retrain-iter 63: 0.000611448
# Retrain-iter 64: 0.00128277
# Retrain-iter 65: 0.000615999
# Retrain-iter 66: 0.000875913
# Retrain-iter 67: 0.00065615
# Retrain-iter 68: 0.00153601
# Retrain-iter 69: 0.000367822
# Retrain-iter 70: 0.000779392
# Retrain-iter 71: 0.000785483
# Retrain-iter 72: 0.00160386
# Retrain-iter 73: 0.000495339
# Retrain-iter 74: 0.000635316
# Retrain-iter 75: 0.000609633
# Retrain-iter 76: 0.000511864
# Retrain-iter 77: 0.000372532
# Retrain-iter 78: 0.00177032
# Retrain-iter 79: 0.00171655
# Retrain-iter 80: 0.000361648
# Retrain-iter 81: 0.00136484
# Retrain-iter 82: 0.00127252
# Retrain-iter 83: 0.00125592
# Retrain-iter 84: 0.000861181
# Retrain-iter 85: 0.00114608
# Retrain-iter 86: 0.00079846
# Retrain-iter 87: 0.000482442
# Retrain-iter 88: 0.00199489
# Retrain-iter 89: 0.00043109
# Retrain-iter 90: 0.000393922
# Retrain-iter 91: 0.000343208
# Retrain-iter 92: 0.00200216
# Retrain-iter 93: 0.00087141
# Retrain-iter 94: 0.000591404
# Retrain-iter 95: 0.00134817
# Retrain-iter 96: 0.000894355
# Retrain-iter 97: 0.00126495
# Retrain-iter 98: 0.00125746
# Retrain-iter 99: 0.00053168
# Retrain-iter 100: 0.000617565
# Score-26268852224.000,threshold1767522380.800
# Correct prediction!!!
# Score-9798349824.000,threshold1767522380.800
# Correct prediction!!!
# Score-2871664384.000,threshold1767522380.800
# Correct prediction!!!
# Retrain at batch number 23
#
# Retrain-iter 1: 0.0017234
# Retrain-iter 2: 0.00175912
# Retrain-iter 3: 0.00356122
# Retrain-iter 4: 0.00332594
# Retrain-iter 5: 0.0016356
# Retrain-iter 6: 0.00175499
# Retrain-iter 7: 0.00312878
# Retrain-iter 8: 0.00310328
# Retrain-iter 9: 0.00300223
# Retrain-iter 10: 0.00181198
# Retrain-iter 11: 0.00288181
# Retrain-iter 12: 0.00167792
# Retrain-iter 13: 0.00169954
# Retrain-iter 14: 0.00151622
# Retrain-iter 15: 0.00296843
# Retrain-iter 16: 0.00167143
# Retrain-iter 17: 0.00293986
# Retrain-iter 18: 0.00151758
# Retrain-iter 19: 0.00280101
# Retrain-iter 20: 0.00162066
# Retrain-iter 21: 0.0026829
# Retrain-iter 22: 0.00162604
# Retrain-iter 23: 0.0016387
# Retrain-iter 24: 0.00159623
# Retrain-iter 25: 0.0015021
# Retrain-iter 26: 0.00270868
# Retrain-iter 27: 0.00274127
# Retrain-iter 28: 0.00270358
# Retrain-iter 29: 0.00145233
# Retrain-iter 30: 0.00146925
# Retrain-iter 31: 0.00258782
# Retrain-iter 32: 0.00162442
# Retrain-iter 33: 0.00253664
# Retrain-iter 34: 0.00249914
# Retrain-iter 35: 0.00158519
# Retrain-iter 36: 0.00155147
# Retrain-iter 37: 0.00245936
# Retrain-iter 38: 0.00148136
# Retrain-iter 39: 0.00248129
# Retrain-iter 40: 0.00161142
# Retrain-iter 41: 0.00248271
# Retrain-iter 42: 0.00246384
# Retrain-iter 43: 0.00153379
# Retrain-iter 44: 0.00149817
# Retrain-iter 45: 0.00159209
# Retrain-iter 46: 0.00251537
# Retrain-iter 47: 0.0014205
# Retrain-iter 48: 0.00141511
# Retrain-iter 49: 0.00160681
# Retrain-iter 50: 0.0013961
# Retrain-iter 51: 0.00156192
# Retrain-iter 52: 0.00257007
# Retrain-iter 53: 0.00251024
# Retrain-iter 54: 0.00143549
# Retrain-iter 55: 0.00143582
# Retrain-iter 56: 0.00143107
# Retrain-iter 57: 0.00141156
# Retrain-iter 58: 0.00180101
# Retrain-iter 59: 0.0013324
# Retrain-iter 60: 0.00132112
# Retrain-iter 61: 0.0027483
# Retrain-iter 62: 0.00157317
# Retrain-iter 63: 0.00149936
# Retrain-iter 64: 0.00141768
# Retrain-iter 65: 0.00279353
# Retrain-iter 66: 0.00135595
# Retrain-iter 67: 0.00156858
# Retrain-iter 68: 0.0027105
# Retrain-iter 69: 0.002638
# Retrain-iter 70: 0.00154909
# Retrain-iter 71: 0.002523
# Retrain-iter 72: 0.00162739
# Retrain-iter 73: 0.0014656
# Retrain-iter 74: 0.0015285
# Retrain-iter 75: 0.0025183
# Retrain-iter 76: 0.00146529
# Retrain-iter 77: 0.00143525
# Retrain-iter 78: 0.00141362
# Retrain-iter 79: 0.00152934
# Retrain-iter 80: 0.00274264
# Retrain-iter 81: 0.00140095
# Retrain-iter 82: 0.00145197
# Retrain-iter 83: 0.00145585
# Retrain-iter 84: 0.00139685
# Retrain-iter 85: 0.00147278
# Retrain-iter 86: 0.00145458
# Retrain-iter 87: 0.00258321
# Retrain-iter 88: 0.0013959
# Retrain-iter 89: 0.00140673
# Retrain-iter 90: 0.00256726
# Retrain-iter 91: 0.00136585
# Retrain-iter 92: 0.00142409
# Retrain-iter 93: 0.00142467
# Retrain-iter 94: 0.00254201
# Retrain-iter 95: 0.00138765
# Retrain-iter 96: 0.00140137
# Retrain-iter 97: 0.00137333
# Retrain-iter 98: 0.00139286
# Retrain-iter 99: 0.00133421
# Retrain-iter 100: 0.00132193
# Score-10039160832.000,threshold1767522380.800
# Correct prediction!!!
# Score-5207467008.000,threshold1767522380.800
# Correct prediction!!!
# Score-31176206336.000,threshold1767522380.800
# Correct prediction!!!
# Score-3978424064.000,threshold1767522380.800
# Correct prediction!!!
# Retrain at batch number 28
#
# Retrain-iter 1: 0.00235579
# Retrain-iter 2: 0.00218442
# Retrain-iter 3: 0.00195319
# Retrain-iter 4: 0.00168447
# Retrain-iter 5: 0.00217284
# Retrain-iter 6: 0.00166389
# Retrain-iter 7: 0.00176897
# Retrain-iter 8: 0.00223124
# Retrain-iter 9: 0.00205388
# Retrain-iter 10: 0.00187779
# Retrain-iter 11: 0.00160524
# Retrain-iter 12: 0.00146566
# Retrain-iter 13: 0.00149109
# Retrain-iter 14: 0.0024285
# Retrain-iter 15: 0.00239869
# Retrain-iter 16: 0.00220343
# Retrain-iter 17: 0.00193342
# Retrain-iter 18: 0.00168517
# Retrain-iter 19: 0.00217831
# Retrain-iter 20: 0.00177495
# Retrain-iter 21: 0.00184855
# Retrain-iter 22: 0.00223992
# Retrain-iter 23: 0.0022335
# Retrain-iter 24: 0.00156652
# Retrain-iter 25: 0.00179964
# Retrain-iter 26: 0.00171647
# Retrain-iter 27: 0.00170639
# Retrain-iter 28: 0.00183857
# Retrain-iter 29: 0.0017974
# Retrain-iter 30: 0.00175593
# Retrain-iter 31: 0.00162351
# Retrain-iter 32: 0.00181226
# Retrain-iter 33: 0.00180239
# Retrain-iter 34: 0.00188711
# Retrain-iter 35: 0.00190053
# Retrain-iter 36: 0.00177847
# Retrain-iter 37: 0.00170806
# Retrain-iter 38: 0.00157153
# Retrain-iter 39: 0.00161476
# Retrain-iter 40: 0.00179887
# Retrain-iter 41: 0.00178129
# Retrain-iter 42: 0.00200548
# Retrain-iter 43: 0.00182339
# Retrain-iter 44: 0.00169639
# Retrain-iter 45: 0.0016704
# Retrain-iter 46: 0.00163723
# Retrain-iter 47: 0.00155098
# Retrain-iter 48: 0.00177813
# Retrain-iter 49: 0.00138296
# Retrain-iter 50: 0.00134722
# Retrain-iter 51: 0.00131744
# Retrain-iter 52: 0.00127697
# Retrain-iter 53: 0.00123059
# Retrain-iter 54: 0.00199461
# Retrain-iter 55: 0.00199151
# Retrain-iter 56: 0.00193247
# Retrain-iter 57: 0.00128223
# Retrain-iter 58: 0.00180859
# Retrain-iter 59: 0.00173338
# Retrain-iter 60: 0.00133154
# Retrain-iter 61: 0.00159662
# Retrain-iter 62: 0.00132968
# Retrain-iter 63: 0.00154773
# Retrain-iter 64: 0.00154091
# Retrain-iter 65: 0.00210332
# Retrain-iter 66: 0.00153048
# Retrain-iter 67: 0.00165944
# Retrain-iter 68: 0.00194185
# Retrain-iter 69: 0.00142988
# Retrain-iter 70: 0.00192695
# Retrain-iter 71: 0.0014213
# Retrain-iter 72: 0.00174229
# Retrain-iter 73: 0.0018236
# Retrain-iter 74: 0.00166624
# Retrain-iter 75: 0.00173309
# Retrain-iter 76: 0.00162173
# Retrain-iter 77: 0.00154094
# Retrain-iter 78: 0.001586
# Retrain-iter 79: 0.00163208
# Retrain-iter 80: 0.00163125
# Retrain-iter 81: 0.00207101
# Retrain-iter 82: 0.00163528
# Retrain-iter 83: 0.00171814
# Retrain-iter 84: 0.00156722
# Retrain-iter 85: 0.00195857
# Retrain-iter 86: 0.00148754
# Retrain-iter 87: 0.00146746
# Retrain-iter 88: 0.00158057
# Retrain-iter 89: 0.00164501
# Retrain-iter 90: 0.00158581
# Retrain-iter 91: 0.00193604
# Retrain-iter 92: 0.00162069
# Retrain-iter 93: 0.00161952
# Retrain-iter 94: 0.00217259
# Retrain-iter 95: 0.00183466
# Retrain-iter 96: 0.0016644
# Retrain-iter 97: 0.00198342
# Retrain-iter 98: 0.00155199
# Retrain-iter 99: 0.00192182
# Retrain-iter 100: 0.00154308
# Score-27551084544.000,threshold1767522380.800
# Correct prediction!!!
# Score-27559006208.000,threshold1767522380.800
# Correct prediction!!!
# Score-14956329984.000,threshold1767522380.800
# Correct prediction!!!
# Score-11136993280.000,threshold1767522380.800
# Correct prediction!!!
# Score-4352672256.000,threshold1767522380.800
# Correct prediction!!!
# Score-668831296.000,threshold1767522380.800
# Correct prediction!!!
# Score-6648244224.000,threshold1767522380.800
# Correct prediction!!!
# Retrain at batch number 35
#
# Retrain-iter 1: 0.00235686
# Retrain-iter 2: 0.00191982
# Retrain-iter 3: 0.00386842
# Retrain-iter 4: 0.00342685
# Retrain-iter 5: 0.00294246
# Retrain-iter 6: 0.00271728
# Retrain-iter 7: 0.00270043
# Retrain-iter 8: 0.00226145
# Retrain-iter 9: 0.00306307
# Retrain-iter 10: 0.00295855
# Retrain-iter 11: 0.00188576
# Retrain-iter 12: 0.00186795
# Retrain-iter 13: 0.00166468
# Retrain-iter 14: 0.00343386
# Retrain-iter 15: 0.00357187
# Retrain-iter 16: 0.00285312
# Retrain-iter 17: 0.00256475
# Retrain-iter 18: 0.00194749
# Retrain-iter 19: 0.00194192
# Retrain-iter 20: 0.00173599
# Retrain-iter 21: 0.00166552
# Retrain-iter 22: 0.00347637
# Retrain-iter 23: 0.00289815
# Retrain-iter 24: 0.00184142
# Retrain-iter 25: 0.00189685
# Retrain-iter 26: 0.00138457
# Retrain-iter 27: 0.00347525
# Retrain-iter 28: 0.00154296
# Retrain-iter 29: 0.00275005
# Retrain-iter 30: 0.00286854
# Retrain-iter 31: 0.00269478
# Retrain-iter 32: 0.00305643
# Retrain-iter 33: 0.00259307
# Retrain-iter 34: 0.00178282
# Retrain-iter 35: 0.00310414
# Retrain-iter 36: 0.00169783
# Retrain-iter 37: 0.00275893
# Retrain-iter 38: 0.00263781
# Retrain-iter 39: 0.00303464
# Retrain-iter 40: 0.00288693
# Retrain-iter 41: 0.00231917
# Retrain-iter 42: 0.00242256
# Retrain-iter 43: 0.00253329
# Retrain-iter 44: 0.0023904
# Retrain-iter 45: 0.00223162
# Retrain-iter 46: 0.0019378
# Retrain-iter 47: 0.00229371
# Retrain-iter 48: 0.00255543
# Retrain-iter 49: 0.00334509
# Retrain-iter 50: 0.00152123
# Retrain-iter 51: 0.00298261
# Retrain-iter 52: 0.00274369
# Retrain-iter 53: 0.00182042
# Retrain-iter 54: 0.00191002
# Retrain-iter 55: 0.00273838
# Retrain-iter 56: 0.0018225
# Retrain-iter 57: 0.0026008
# Retrain-iter 58: 0.00250338
# Retrain-iter 59: 0.00241356
# Retrain-iter 60: 0.00290409
# Retrain-iter 61: 0.00221517
# Retrain-iter 62: 0.00168758
# Retrain-iter 63: 0.00321811
# Retrain-iter 64: 0.00240013
# Retrain-iter 65: 0.00270216
# Retrain-iter 66: 0.00176895
# Retrain-iter 67: 0.00256785
# Retrain-iter 68: 0.00250377
# Retrain-iter 69: 0.00248023
# Retrain-iter 70: 0.00284054
# Retrain-iter 71: 0.00242462
# Retrain-iter 72: 0.00224424
# Retrain-iter 73: 0.0024928
# Retrain-iter 74: 0.00250023
# Retrain-iter 75: 0.00162002
# Retrain-iter 76: 0.0026098
# Retrain-iter 77: 0.00147127
# Retrain-iter 78: 0.0028003
# Retrain-iter 79: 0.00143376
# Retrain-iter 80: 0.00266102
# Retrain-iter 81: 0.00252528
# Retrain-iter 82: 0.0016682
# Retrain-iter 83: 0.00242324
# Retrain-iter 84: 0.00171376
# Retrain-iter 85: 0.0024816
# Retrain-iter 86: 0.00155491
# Retrain-iter 87: 0.00143788
# Retrain-iter 88: 0.00269743
# Retrain-iter 89: 0.00272064
# Retrain-iter 90: 0.00262872
# Retrain-iter 91: 0.00264672
# Retrain-iter 92: 0.00245649
# Retrain-iter 93: 0.0018575
# Retrain-iter 94: 0.00257203
# Retrain-iter 95: 0.00249048
# Retrain-iter 96: 0.00274238
# Retrain-iter 97: 0.00193487
# Retrain-iter 98: 0.00235844
# Retrain-iter 99: 0.00148845
# Retrain-iter 100: 0.00136353
# Score-2499207936.000,threshold1767522380.800
# Correct prediction!!!
# Score-3097563648.000,threshold1767522380.800
# Correct prediction!!!

# %%
pd.Series(scoreBuffer).plot() # 12

# %%
pd.Series(scoreBuffer).plot() #51

# %%
foo = [sum(bar)[0] for bar in errBuffer]

# %%
pd.Series(foo).plot()

# %%
pd.Series(errBuffer).plot()  # 51 sum(abs(err-mu))

# %%
foo = pd.Series(np.array(input_buffer).ravel())
bar = pd.Series(np.array(output_buffer).ravel())
foobar = pd.concat((foo,bar),axis=1)

#foobar.to_csv("C:/Users/Bin/Desktop/Thesis/Synthetic example (Power demand dataset)/retrain_p1/retraining_if_error_larger_than_error0.csv",header=['input','output'],index=None)

# %%
# reconstruction error of normal data(retrain after each batch)

normal =pd.DataFrame( foobar[label[1008+84:]== 'normal'])
abnormal =pd.DataFrame( foobar[label[1008+84:]== 'anomaly'])

error1 = abs( normal[0]- normal[1])
error2 = abs( abnormal[0]- abnormal[1])
error1.plot()
error2.plot()
plt.xlim(-30,error1.size+error2.size)
plt.title("Reconstruction error (retrain_if_error_larger_than_error0)")
print("Normal: Max %.2f, min %.2f, avg %.2f, median %.2f"%(max(error1),min(error1), np.mean(error1),np.median(error1)))
print("Abnormal: Max %.2f, min %.2f, avg %.2f, median %.2f"%(max(error2),min(error2), np.mean(error2),np.median(error2)))
# Out:
# Normal: Max 0.29, min 0.00, avg 0.03, median 0.03
# Abnormal: Max 0.47, min 0.00, avg 0.07, median 0.04

# %%
# statistical results in batch
normal_batches = [error1[i*(batch_num*step_num):(i+1)*(batch_num*step_num)]for i in range(error1.size//(batch_num*step_num))]
abnormal_batches = [error2[i*(batch_num*step_num):(i+1)*(batch_num*step_num)]for i in range(error2.size//(batch_num*step_num))]

batch_error1  = pd.DataFrame([[max(x),min(x),np.mean(x),np.median(x)] for x in normal_batches])
batch_error2  = pd.DataFrame([[max(y),min(y),np.mean(y),np.median(y)] for y in abnormal_batches])

#batch_error1.to_csv("C:/Users/Bin/Desktop/Thesis/Synthetic example (Power demand dataset)/retrain_p1/normal_retraining(batch).csv",header=['max','min','avg','median'],index=None)
#batch_error2.to_csv("C:/Users/Bin/Desktop/Thesis/Synthetic example (Power demand dataset)/retrain_p1/abnormal_retraining(batch).csv",header=['max','min','avg','median'],index=None)

# %%
error0 =  abs( foobar[0]- foobar[1])
all_batches = [error0[i*(batch_num*step_num):(i+1)*(batch_num*step_num)]for i in range(error0.size//(batch_num*step_num))]
batch_error0  = pd.DataFrame([[max(x),min(x),np.mean(x),np.median(x)] for x in all_batches])
batch_error0.to_csv("C:/Users/Bin/Desktop/Thesis/Synthetic example (Power demand dataset)/retrain_p1/all_retraining(batch).csv",header=['max','min','avg','median'],index=None)

# %%
data = foobar
#data = pd.read_csv("C:/Users/Bin/Desktop/Thesis/Synthetic example (Power demand dataset)/retrain_p1/retraining_if_error_larger_than_error0.csv")

# %%
fig, axes = plt.subplots(nrows=4, ncols=1,figsize=(20,20))
axes[0].set_title("Retraining according to performance(P1): batch_num=1, #hidden layer units=40, time_steps=84")
data[:840].plot(ax=axes[0])
data[840*1:840*2].plot(ax=axes[1])
data[840*2:840*3].plot(ax=axes[2])
data[840*3:].plot(ax=axes[3])

# %%
fig, (ax0,ax1) = plt.subplots(nrows=1, ncols=2,figsize=(20,5))
plt.suptitle("Anomaly No.4 and No.5 (Retrain when error.max larger than initial error.max)", fontsize=20)
data[84*26:84*27].plot(ax=ax0,color=['blue','black'])
data[-84:].plot(ax=ax1,color=['blue','black'])
ax0.set_facecolor('darkorchid')
ax1.set_facecolor('darkorchid')
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
fig, (ax0,ax1,ax2) = plt.subplots(nrows=1, ncols=3,figsize=(25,5))
#plt.suptitle("Befor & after retraining")
data[84*12:84*13].plot(ax=ax0,color=['blue','black'])
data[84*13:84*14].plot(ax=ax1,color=['blue','black'])
data[84*14:84*15].plot(ax=ax2,color=['blue','black'])
ax0.set_facecolor('darkorchid')
ax1.set_facecolor('darkorchid')
ax2.set_facecolor('darkorchid')
ax0.set_title("Befor retraining", fontsize=20)
ax1.set_title("Befor retraining (retraining after this batch)", fontsize=20)
ax2.set_title("After retraining", fontsize=20)
ax0.set_ylim(0,0.8)
ax1.set_ylim(0,0.8)
ax2.set_ylim(0,0.8)
# Out:
# (0, 0.8)
